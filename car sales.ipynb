# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Car_sales.csv')
print(df)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0         Acura      Integra              16.919               16.360
# 1         Acura           TL              39.384               19.875
# 2         Acura           CL              14.114               18.225
# 3         Acura           RL               8.588               29.725
# 4          Audi           A4              20.397               22.255
# 5          Audi           A6              18.780               23.555
# 6          Audi           A8               1.380               39.000
# 7           BMW         323i              19.747                  NaN
# 8           BMW         328i               9.231               28.675
# 9           BMW         528i              17.527               36.125
# 10        Buick      Century              91.561               12.475
# 11        Buick        Regal              39.350               13.740
# ...

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df.reset_index(inplace=True)
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
indexedData = df.set_index('Manufacturer')
indexedData
# Out:
#                 Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# Manufacturer
# Acura         Integra              16.919               16.360    Passenger
# Acura              TL              39.384               19.875    Passenger
# Acura              CL              14.114               18.225    Passenger
# Acura              RL               8.588               29.725    Passenger
# Audi               A4              20.397               22.255    Passenger
# ...               ...                 ...                  ...          ...
# Volvo             V40               3.545                  NaN    Passenger
# Volvo             S70              15.245                  NaN    Passenger
# Volvo             V70              17.531                  NaN    Passenger
# Volvo             C70               3.493                  NaN    Passenger
# Volvo             S80              18.969                  NaN    Passenger
#
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.index[1]
# Out:
# 1

# %%
df.columns[1]
# Out:
# 'Model'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.size
# Out:
# 2512

# %%
df.shape
# Out:
# (157, 16)

# %%
df.dtypes
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# # Indexing, Selection, and Slicing

# %%
df['Manufacturer']
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4       Audi
#        ...
# 152    Volvo
# 153    Volvo
# 154    Volvo
# 155    Volvo
# 156    Volvo
# Name: Manufacturer, Length: 157, dtype: object

# %%
df['Manufacturer'].to_frame()
# Out:
#     Manufacturer
# 0          Acura
# 1          Acura
# 2          Acura
# 3          Acura
# 4           Audi
# ..           ...
# 152        Volvo
# 153        Volvo
# 154        Volvo
# 155        Volvo
# 156        Volvo
#
# [157 rows x 1 columns]

# %%
df[['Manufacturer', 'Model']]
# Out:
#     Manufacturer    Model
# 0          Acura  Integra
# 1          Acura       TL
# 2          Acura       CL
# 3          Acura       RL
# 4           Audi       A4
# ..           ...      ...
# 152        Volvo      V40
# 153        Volvo      S70
# 154        Volvo      V70
# 155        Volvo      C70
# 156        Volvo      S80
#
# [157 rows x 2 columns]

# %%
df[1:3]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 1        Acura    TL              39.384               19.875    Passenger
# 2        Acura    CL              14.114               18.225    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 1                28.4          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
#
#    Power_perf_factor
# 1          91.370778
# 2                NaN

# %%
df.loc[1]
# Out:
# Manufacturer               Acura
# Model                         TL
# Sales_in_thousands        39.384
# __year_resale_value       19.875
# Vehicle_type           Passenger
# Price_in_thousands          28.4
# Engine_size                  3.2
# Horsepower                 225.0
# Wheelbase                  108.1
# Width                       70.3
# Length                     192.9
# Curb_weight                3.517
# Fuel_capacity               17.2
# Fuel_efficiency             25.0
# Latest_Launch           6/3/2011
# Power_perf_factor      91.370778
# Name: 1, dtype: object

# %%
df.loc[df['Manufacturer'] == 'BMW']
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 7          BMW  323i              19.747                  NaN    Passenger
# 8          BMW  328i               9.231               28.675    Passenger
# 9          BMW  528i              17.527               36.125    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 7               26.99          2.5       170.0      107.3   68.4   176.0
# 8               33.40          2.8       193.0      107.3   68.5   176.0
# 9               38.90          2.8       193.0      111.4   70.9   188.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 7        3.179           16.6             26.0     6/28/2011
# 8        3.197           16.6             24.0     1/29/2012
# 9        3.472           18.5             25.0      4/4/2011
#
#    Power_perf_factor
# 7          71.191207
# 8          81.877069
# 9          83.998724

# %%
df.iloc[-1]
# Out:
# Manufacturer                Volvo
# Model                         S80
# Sales_in_thousands         18.969
# __year_resale_value           NaN
# Vehicle_type            Passenger
# Price_in_thousands           36.0
# Engine_size                   2.9
# Horsepower                  201.0
# Wheelbase                   109.9
# Width                        72.1
# Length                      189.8
# Curb_weight                   3.6
# Fuel_capacity                21.1
# Fuel_efficiency              24.0
# Latest_Launch          11/14/2011
# Power_perf_factor       85.735655
# Name: 156, dtype: object

# %%
df.iloc[1:2]
# Out:
#   Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 1        Acura    TL              39.384               19.875    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 1                28.4          3.2       225.0      108.1   70.3   192.9
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 1        3.517           17.2             25.0      6/3/2011
#
#    Power_perf_factor
# 1          91.370778

# %%
df.iloc[-1:]
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
#      Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 156          3.6           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 156          85.735655

# %%
df.iloc[[0, 1, -1]]
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger                21.5          1.8       140.0      101.2
# 1      Passenger                28.4          3.2       225.0      108.1
# 156    Passenger                36.0          2.9       201.0      109.9
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0     67.3   172.4        2.639           13.2             28.0      2/2/2012
# 1     70.3   192.9        3.517           17.2             25.0      6/3/2011
# 156   72.1   189.8        3.600           21.1             24.0    11/14/2011
#
#      Power_perf_factor
# 0            58.280150
# 1            91.370778
# ...

# %%
df.iloc[1:3, 3]
# Out:
# 1    19.875
# 2    18.225
# Name: __year_resale_value, dtype: float64

# %%
df.iloc[1:3, [1,3]]
# Out:
#   Model  __year_resale_value
# 1    TL               19.875
# 2    CL               18.225

# %%
df.iloc[1:3, 1:3]
# Out:
#   Model  Sales_in_thousands
# 1    TL              39.384
# 2    CL              14.114

# %% [markdown]
# # Conditional Selection (boolean arrays)

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df['Fuel_efficiency'] > 25.0
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 152    False
# 153    False
# 154    False
# 155    False
# 156    False
# Name: Fuel_efficiency, Length: 157, dtype: bool

# %%
df.loc[df['Fuel_efficiency'] > 25.0]
# Out:
#     Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura      Integra              16.919               16.360
# 2          Acura           CL              14.114               18.225
# 4           Audi           A4              20.397               22.255
# 7            BMW         323i              19.747                  NaN
# 19     Chevrolet     Cavalier             145.519                9.250
# 22     Chevrolet  Monte Carlo              42.593               11.525
# 25     Chevrolet        Prizm              32.299                9.125
# 26     Chevrolet        Metro              21.855                5.160
# 27     Chevrolet       Impala             107.995                  NaN
# 30      Chrysler     Concorde              31.148               13.725
# 31      Chrysler       Cirrus              32.306               12.640
# 35         Dodge         Neon              76.034                7.750
# ...

# %%
df.loc[df['Fuel_efficiency'] > 25.0, 'Fuel_efficiency']
# Out:
# 0      28.0
# 2      26.0
# 4      27.0
# 7      26.0
# 19     27.0
# 22     27.0
# 25     33.0
# 26     45.0
# 27     27.0
# 30     26.0
# 31     27.0
# 35     29.0
# 46     30.0
# 50     30.0
# 57     32.0
# 58     27.0
# 62     31.0
# 63     27.0
# 79     30.0
# 86     28.0
# 87     30.0
# 92     26.0
# 96     26.0
# 97     27.0
# 98     26.0
# 101    30.0
# 110    27.0
# 114    29.0
# 115    27.0
# 118    27.0
# 129    33.0
# 130    33.0
# 131    31.0
# 132    27.0
# 133    28.0
# 136    33.0
# 137    27.0
# 138    26.0
# 139    31.0
# 142    27.0
# 145    26.0
# 146    26.0
# 147    27.0
# 148    26.0
# 149    26.0
# 150    26.0
# Name: Fuel_efficiency, dtype: float64

# %% [markdown]
# # Dropping Stuff

# %%
df.drop(10)
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.drop(columns=['Manufacturer', 'Model'])
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0                16.919               16.360    Passenger               21.50
# 1                39.384               19.875    Passenger               28.40
# 2                14.114               18.225    Passenger                 NaN
# 3                 8.588               29.725    Passenger               42.00
# 4                20.397               22.255    Passenger               23.99
# ..                  ...                  ...          ...                 ...
# 152               3.545                  NaN    Passenger               24.40
# 153              15.245                  NaN    Passenger               27.50
# 154              17.531                  NaN    Passenger               28.80
# 155               3.493                  NaN    Passenger               45.50
# 156              18.969                  NaN    Passenger               36.00
#
# ...

# %%
df.drop(columns=['Manufacturer', 'Model'], axis=1)
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0                16.919               16.360    Passenger               21.50
# 1                39.384               19.875    Passenger               28.40
# 2                14.114               18.225    Passenger                 NaN
# 3                 8.588               29.725    Passenger               42.00
# 4                20.397               22.255    Passenger               23.99
# ..                  ...                  ...          ...                 ...
# 152               3.545                  NaN    Passenger               24.40
# 153              15.245                  NaN    Passenger               27.50
# 154              17.531                  NaN    Passenger               28.80
# 155               3.493                  NaN    Passenger               45.50
# 156              18.969                  NaN    Passenger               36.00
#
# ...

# %%
df.drop(['Manufacturer', 'Model'], axis='columns')
# Out:
#      Sales_in_thousands  __year_resale_value Vehicle_type  Price_in_thousands  \
# 0                16.919               16.360    Passenger               21.50
# 1                39.384               19.875    Passenger               28.40
# 2                14.114               18.225    Passenger                 NaN
# 3                 8.588               29.725    Passenger               42.00
# 4                20.397               22.255    Passenger               23.99
# ..                  ...                  ...          ...                 ...
# 152               3.545                  NaN    Passenger               24.40
# 153              15.245                  NaN    Passenger               27.50
# 154              17.531                  NaN    Passenger               28.80
# 155               3.493                  NaN    Passenger               45.50
# 156              18.969                  NaN    Passenger               36.00
#
# ...

# %% [markdown]
# # Modifying Dataframes

# %% [markdown]
# # Adding New Column

# %%
number = pd.Series(
    ['two', 'four', 'six', 'eight'],
    index = [0, 4, 6, 152],
    name = 'number'
# Out:
#   File "C:\Users\Acer\AppData\Local\Temp/ipykernel_6568/93823024.py", line 4
#     name = 'number'
#                    ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Statistical Info

# %%
df.head()

# %%
df.describe()

# %%
Price_in_thousands = df['Price_in_thousands']

# %%
Price_in_thousands.min(), Price_in_thousands.max()

# %%
Price_in_thousands.sum()

# %%
len(Price_in_thousands)

# %%
Price_in_thousands.sum()/len(Price_in_thousands)

# %%
Price_in_thousands.mean()

# %%
Price_in_thousands.std()

# %%
Price_in_thousands.median()

# %%
Price_in_thousands.describe()

# %%
Price_in_thousands.quantile(.25)

# %%
Price_in_thousands.quantile([.2, .4, .6, .8, 1])
